# %% [markdown]
# # Multi-Class classification example

# %%
import sys
import sklearn
import numpy as np
import os
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# to make this notebook's output stable across runs
np.random.seed(42)

# %% [markdown]
# ## Download MNIST dataset

# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version=1, as_frame=False)

# %%
# Extract X and y
X, y = mnist["data"], mnist["target"]

# %%
# X is composed of 70K images (hand-writen digits) of size 28x28, but they are saved in a 1D vector instead of 2D
X.shape
# Out:
# (70000, 784)

# %%
28 * 28
# Out:
# 784

# %%
# The labels go from 0 to 9, and indicate the hand-writen digit of the image
y.shape
# Out:
# (70000,)

# %%
y
# Out:
# array(['5', '0', '4', ..., '4', '5', '6'], dtype=object)

# %%
# Function to plot one example (sample) of the data
def plot_digit(data):
    image = data.reshape(28, 28)
    plt.imshow(image, cmap = mpl.cm.binary,
               interpolation="nearest")
    plt.axis("off")

# %%
plot_digit(X[2])

# %% [markdown]
# Why do we call the **reshape** function?

# %%
# What is the label of the first image? Does it correspond to the number you observed in the image?
y[0]
# Out:
# '5'

# %%
# Change the labels to numerical values (type: uint8)
# Use function astype

# %%
# Manually split the data intro training and testing sets
# Select the first 60K images for training and the rest for testing

# %%
# Count the number of occurrences of each digit in the training and test set
# to make sure all digits are represented in the sets

# %% [markdown]
# # Multiclass Classification

# %% [markdown]
# Train a softmax classifier on the training set

# %% [markdown]
# Try first normalizing the input data: it is enough to divide the input by 255, why?

# %%
# Use the logistic regression model from sklearn

# instantiate the model (using max_iter = 2000 and random_state=42)

# fit the model to the training data

# %% [markdown]
# Check the performance on the test set by computing the accuracy and ploting the confusion matrix. Do you extract any conclusions from the confusion matrix?

# %% [markdown]
# Note: Before applying the model on the test set, think if there are any transformations you need to apply to the test set!
